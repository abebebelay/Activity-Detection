# %% [markdown]
# **Step 1: Install Requirements**

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_DeepSort_Pytorch.git  # clone repo
# %cd Yolov5_DeepSort_Pytorch
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla K80)

# %% [markdown]
# **Step 2: Assemple Dataset: Upload,Unzip and Ready For Model To train and test**

# %%
#unzip labels data
# !unzip -q ../Public_Dataset.zip -d ../
print("done")
# Out:
# done

# %%
#unzip labels data
# !unzip -q ../labels.zip -d ../
print("done")
# Out:
# done

# %%
#unzip trainimg1 data
# !unzip -q ../trainimg1.zip -d ../
print("done")
# Out:
# done

# %%
#unzip trainimg2 data
# !unzip -q ../trainimg2.zip -d ../
print("done")
# Out:
# done

# %%
#unzip trainimg3 data
# !unzip -q ../trainimg3.zip -d ../
print("done")
# Out:
# done

# %%
#unzip trainimg4 data
# !unzip -q ../trainimg4.zip -d ../
print("done")
# Out:
# done

# %%
#unzip trainimg5 data
# !unzip -q ../trainimg5.zip -d ../
print("done")
# Out:
# done

# %%
#unzip valimag data
# !unzip -q ../valimg.zip -d ../
print("done")
# Out:
# done

# %%
#unzip testimag data
# !unzip -q ../testimg.zip -d ../
print("done")

# %%
#image file copy from trainimg1 to train
import shutil
import os
count=0
os.chdir('/content/trainimg1/')
dst_dir = '/content/Yolov5_DeepSort_Pytorch/Public_Dataset/images/train/'
for f in os.listdir():
    shutil.copy(f, dst_dir)
    count=count+1
print("number of copying file  ",count)
# Out:
# number of copying file   442

# %%
#image file copy from trainimg2 to train
import shutil
import os
count=0
os.chdir('/content/trainimg2/')
dst_dir = '/content/Yolov5_DeepSort_Pytorch/Public_Dataset/images/train/'
for f in os.listdir():
    shutil.copy(f, dst_dir)
    count=count+1
print("number of copying file  ",count)
# Out:
# number of copying file   381

# %%
#image file copy from trainimg3 to train
import shutil
import os
count=0
os.chdir('/content/trainimg3/')
dst_dir = '/content/Yolov5_DeepSort_Pytorch/Public_Dataset/images/train/'
for f in os.listdir():
    shutil.copy(f, dst_dir)
    count=count+1
print("number of copying file  ",count)
# Out:
# number of copying file   504

# %%
#image file copy from trainimg4 to train
import shutil
import os
count=0
os.chdir('/content/trainimg4/')
dst_dir = '/content/Yolov5_DeepSort_Pytorch/Public_Dataset/images/train/'
for f in os.listdir():
    shutil.copy(f, dst_dir)
    count=count+1
print("number of copying file  ",count)
# Out:
# number of copying file   974

# %%
#image file copy from trainimg5 to train
import shutil
import os
count=0
os.chdir('/content/trainimg5/')
dst_dir = '/content/Yolov5_DeepSort_Pytorch/Public_Dataset/images/train/'
for f in os.listdir():
    shutil.copy(f, dst_dir)
    count=count+1
print("number of copying file  ",count)
# Out:
# number of copying file   1428

# %%
#image file copy from valimg to val
import shutil
import os
count=0
os.chdir('/content/valimg/')
dst_dir = '/content/Yolov5_DeepSort_Pytorch/Public_Dataset/images/val/'
for f in os.listdir():
    shutil.copy(f, dst_dir)
    count=count+1
print("number of copying file  ",count)
# Out:
# number of copying file   467

# %%
#count The Number of Dataset under val folder
import os
valimg=len(os.listdir('/content/Yolov5_DeepSort_Pytorch/Public_Dataset/images/val'))
vallabel=len(os.listdir('/content/Yolov5_DeepSort_Pytorch/Public_Dataset/labels/val/'))
print("Validation Image:",valimg) 
print("Validation Label:",vallabel)
# Out:
# Validation Image: 467
# Validation Label: 467

# %%
#count The Number of Dataset under train folder
import os
trainimg=len(os.listdir('/content/Yolov5_DeepSort_Pytorch/Public_Dataset/images/train/'))
tranlabel=len(os.listdir('/content/Yolov5_DeepSort_Pytorch/Public_Dataset/labels/train/'))
print("Training Image:",trainimg) 
print("Training Label:",tranlabel)
# Out:
# Training Image: 3729
# Training Label: 3729

# %% [markdown]
# ***Step 3: Upload and check , Dataset Class, Current working directory, show pre trained Model configurations ***

# %%
# %pwd
# Out:
# '/content'

# %%
#Change Directory 
# %cd //content//Yolov5_DeepSort_Pytorch//yolov5
# Out:
# /content/Yolov5_DeepSort_Pytorch/yolov5

# %%
#Show current Directory 
# %pwd
# Out:
# '/content/Yolov5_DeepSort_Pytorch'

# %%
#show  classes, which is in .yaml file
# %cat data/Activities.yaml
# Out:
# train: ../Public_Dataset/images/train/   # train images
# val: ../Public_Dataset/images/val/   # val images
#
#
# nc: 8 # Number of Classes
# names: ['Living_on_static_Place','Moving','Opposing','Phoning','Riding_or_Driving','Supporting','Using_a_computer','Waving_Hands']

# %% [markdown]
# ***Training YOLOV5l Model***

# %%
# !python train.py --img 640 --batch 10 --epochs 5 --data Activities.yaml --weights yolov5l.pt
# Out:
# train: weights=yolov5l.pt, cfg=, data=Activities.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=5, batch_size=10, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# github: ⚠️ YOLOv5 is out of date by 165 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v5.0-430-gaa18599 torch 1.9.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
Image(filename='/content/Yolov5_DeepSort_Pytorch/yolov5/runs/train/exp/confusion_matrix.png', width=1000)

# %%
Image(filename='/content/Yolov5_DeepSort_Pytorch/yolov5/runs/train/exp/R_curve.png', width=1000)

# %%
Image(filename='/content/Yolov5_DeepSort_Pytorch/yolov5/runs/train/exp/P_curve.png', width=1000)

# %%
Image(filename='/content/Yolov5_DeepSort_Pytorch/yolov5/runs/train/exp/PR_curve.png', width=1000)

# %%
Image(filename='/content/Yolov5_DeepSort_Pytorch/yolov5/runs/train/exp/F1_curve.png', width=1000)

# %%
Image(filename='/content/Yolov5_DeepSort_Pytorch/yolov5/runs/train/exp/results.png', width=1000)

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# Run YOLOv5x on COCO val
# !python val.py --weights runs/train/exp/weights/best.pt --data Activities.yaml --img 416
# Out:
# val: data=./data/Activities.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 v5.0-430-gaa18599 torch 1.9.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 444 layers, 86220517 parameters, 0 gradients
# val: Scanning '../Public_Dataset/labels/val.cache' images and labels... 467 found, 0 missing, 0 empty, 0 corrupted: 100% 467/467 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 15/15 [00:23<00:00,  1.56s/it]
#                  all        467        572      0.862      0.926      0.906      0.616
# Living_on_static_Place        467        118      0.971      0.561       0.74      0.512
# ...
